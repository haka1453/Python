# %% [markdown]
# # patV1

# %%
import matplotlib
from matplotlib import pyplot as plt
# matplotlib.__class__

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import matplotlib\nfrom matplotlib import pyplot as plt\n# matplotlib.__class__',
#   'locals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\husey\\Claurusway\\Seaborn'],
#  'In': ['',
#   'import matplotlib\nfrom matplotlib import pyplot as plt\n# matplotlib.__class__',
#   'locals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000011F55A81BB0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x11f55aad850>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x11f55aad850>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__path__': ['C:\\Users\\husey\\anaconda3\\lib\\site-packages\\pyforest'],
# ...

# %%
age = [25,27,29,31,33,35,37,39,41,43,45]
salary = [38496, 42000,46752,49320,53200,
          56000,62316,64928,67317,68748,73752]
plt.plot(age, salary)
plt.show()

# %%
plt.plot(age, salary)
plt.xlabel('plt.xlabel')
plt.ylabel('plt.ylabel')
plt.title('plt.title')
plt.text(age[1], salary[1], s='plt.text')
# Out:
# Text(27, 42000, 'plt.text')

# %%
plt.plot(age, salary)
plt.xlabel('age')
plt.ylabel('salary')
plt.title('salary by age')
# Out:
# Text(0.5, 1.0, 'salary by age')

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998,70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age, salary)
plt.plot(age, salary_2)
plt.xlabel('age')
plt.ylabel('salary')
plt.title('salary by age')
# Out:
# Text(0.5, 1.0, 'salary by age')

# %%
plt.plot(age, salary, label='salary')
plt.plot(age, salary_2, label='salary_2')
plt.xlabel('age')
plt.ylabel('salary')
plt.title('A New Title')
plt.legend()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(age, salary, label='salary')
plt.plot(age, salary_2, label='salary_2')
plt.plot(age, salary, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('age')
plt.ylabel('salary')
plt.title('salaries by age')
plt.legend()

# %%
help(plt.subplot)
# Out:
# Help on function subplot in module matplotlib.pyplot:
#
# subplot(*args, **kwargs)
#     Add an Axes to the current figure or retrieve an existing Axes.
#
#     This is a wrapper of `.Figure.add_subplot` which provides additional
#     behavior when working with the implicit API (see the notes section).
#
#     Call signatures::
#
#        subplot(nrows, ncols, index, **kwargs)
#        subplot(pos, **kwargs)
#        subplot(**kwargs)
#        subplot(ax)
#
#     Parameters
#     ----------
#     *args : int, (int, int, *index*), or `.SubplotSpec`, default: (1, 1, 1)
#         The position of the subplot described by one of
#
#         - Three integers (*nrows*, *ncols*, *index*). The subplot will take the
#           *index* position on a grid with *nrows* rows and *ncols* columns.
#           *index* starts at 1 in the upper left corner and increases to the
#           right. *index* can also be a two-tuple specifying the (*first*,
# ...

# %%
plt.subplot(2,1,1)
plt.plot(age,salary,'r')
plt.subplot(2,1,1)
plt.plot(age,salary_2,'b')  # RGB, hex(web), abbr., whole words...
plt.tight_layout()

# %%
plt.subplot(2,1,1)
plt.subplot(1,2,1)
plt.plot(age,salary, 'black')
plt.subplot(1,2,2)
plt.plot(age,salary, 'orange')
plt.tight_layout()

# %%
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
np.random.seed(19680801)
X = np.linspace(0.5, 3.5, 100)
Y1 = 3*np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1,Y2, len(X))
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,aspect=1)
def minor_tick(x, pos):
    if not x%1.0:
        return ''
    return '%.2f' %x
ax.xaxis.set_major_locator(MultipleLocator(1000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.set_xlim(0,4)
ax.set_ylim(0,4)
ax.tick_params(which='major',width=1.0)
ax.tick_params(which='major',length=10)
ax.tick_params(which='minor',width=1.0, labelsize=10)
ax.tick_params(which='minor',length=5, labelsize=10, labelcolor='0.25')
ax.grid(linestyle='--', linewidth=0.5, color='0.25', zorder=-10)
ax.plot(X,Y1, c=(0.25,0.25,1.00), lw=2, label='Blue signal', zorder=-10)
ax.plot(X,Y2, c=(0.25,0.25,1.00), lw=2, label='Red signal')
ax.plot(X,Y3, linewidth=0,
       marker='o', markerFacecolor='w', markerEdgecolor='k')
ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")
ax.legend()
def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)
def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')
circle(0.50, -0.10)  # Minor tick
text(0.50, -0.32, "Minor tick label")
circle(-0.03, 4.00)  # Major tick
text(0.03, 3.80, "Major tick")
circle(0.00, 3.50)   # Minor tick
text(0.00, 3.30, "Minor tick")
circle(-0.15, 3.00)  # Major tick label
text(-0.15, 2.80, "Major tick label")
circle(1.80, -0.27)  # X Label
text(1.80, -0.45, "X axis label")
circle(-0.27, 1.80)  # Y Label
text(-0.27, 1.6, "Y axis label")
circle(1.60, 4.13)   # Title
text(1.60, 3.93, "Title")
circle(1.75, 2.80)   # Blue plot
text(1.75, 2.60, "Line\n(line plot)")
circle(1.20, 0.60)   # Red plot
text(1.20, 0.40, "Line\n(line plot)")
circle(3.20, 1.75)   # Scatter plot
text(3.20, 1.55, "Markers\n(scatter plot)")
circle(3.00, 3.00)   # Grid
text(3.00, 2.80, "Grid")
circle(3.70, 3.80)   # Legend
text(3.70, 3.60, "Legend")
circle(0.5, 0.5)     # Axes
text(0.5, 0.3, "Axes")
circle(-0.3, 0.65)   # Figure
text(-0.3, 0.45, "Figure")
color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xycoords='data',
            xytext=(3.3, 0.5), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))
ax.annotate('', xy=(3.15, 0.0), xycoords='data',
            xytext=(3.45, 0.45), textcoords='data',
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))
ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')
plt.show()
# Out:
# C:\Users\husey\AppData\Local\Temp/ipykernel_6556/2080341365.py:26: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(X,Y3, linewidth=0,

# %%
plt.subplot(2,2,1)
plt.plot(age,salary, 'r')
plt.subplot(2,2,2)
plt.plot(age,salary, 'b')
plt.subplot(2,2,3)
plt.plot(age,salary_2, 'g')
plt.subplot(2,2,4)
plt.plot(age,salary_2, 'y')
plt.tight_layout()

# %%
import pandas as pd
df = pd.DataFrame(list(zip(age,salary,salary_2)), columns=['age','salary','salary_2'])
df
# Out:
#     age  salary  salary_2
# 0    25   38496     45372
# 1    27   42000     48876
# 2    29   46752     53850
# 3    31   49320     57287
# 4    33   53200     63016
# 5    35   56000     65998
# 6    37   62316     70003
# 7    39   64928     70000
# 8    41   67317     71496
# 9    43   68748     75370
# 10   45   73752     83640

# %%
df['salary']
# Out:
# 0     38496
# 1     42000
# 2     46752
# 3     49320
# 4     53200
# 5     56000
# 6     62316
# 7     64928
# 8     67317
# 9     68748
# 10    73752
# Name: salary, dtype: int64

# %%
plt.plot(age,salary)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, .8, .8])
ax
# Out:
# <Axes:>

# %%
ax.plot(age,salary, 'o')
ax.set_xlabel('Age')
ax.set_ylabel('Salary')
ax.set_title('Salary by Age')
# Out:
# Text(0.5, 1.0, 'Salary by Age')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,.8,.8])
ax2 = fig.add_axes([.9,.3,.4,.4])

# %%
ax1.plot(age,salary,'k')
ax1.set_xlabel('Age')
ax1.set_ylabel('Salary')
ax1.set_title('ax 1 table')
ax2.plot(age,salary_2,'p')
ax2.set_xlabel('Age2')
ax2.set_ylabel('Salary2')
ax2.set_title('ax 2 table')
fig

# %%
ax1
# Out:
# <Axes:title={'center':'ax 1 table'}, xlabel='Age', ylabel='Salary'>

# %%
ax2
# Out:
# <Axes:title={'center':'ax 2 table'}, xlabel='Age2', ylabel='Salary2'>

# %%
fig, ax = plt.subplots(2,2)

# %%
fig

# %%
ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
ax[0,0]
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(2,1)

# %%
fig, ax = plt.subplots(2,1)
b = ax[1].plot(age, salary_2, 'b')
ax[1].set_title('Second Plot')
fig.suptitle('Figure Level', fontsize=16)
plt.tight_layout()

# %%
matplotlib.rcParams==matplotlib.pyplot.rcParams
# Out:
# True

# %%
matplotlib.pyplot.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
help(matplotlib.pyplot)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, *, data=None, **kwargs)
#         Plot the autocorrelation of *x*.
#
#         Parameters
#         ----------
#         x : array-like
#
#         detrend : callable, default: `.mlab.detrend_none` (no detrending)
#             A detrending function applied to *x*.  It must have the
#             signature ::
#
#                 detrend(x: np.ndarray) -> np.ndarray
#
#         normed : bool, default: True
# ...

# %%
help(matplotlib.axes.Axes)
# Out:
# Help on class Axes in module matplotlib.axes._axes:
#
# class Axes(matplotlib.axes._base._AxesBase)
#  |  Axes(fig, rect, *, facecolor=None, frameon=True, sharex=None, sharey=None, label='', xscale=None, yscale=None, box_aspect=None, **kwargs)
#  |
#  |  The `Axes` contains most of the figure elements: `~.axis.Axis`,
#  |  `~.axis.Tick`, `~.lines.Line2D`, `~.text.Text`, `~.patches.Polygon`, etc.,
#  |  and sets the coordinate system.
#  |
#  |  The `Axes` instance supports callbacks through a callbacks attribute which
#  |  is a `~.cbook.CallbackRegistry` instance.  The events you can connect to
#  |  are 'xlim_changed' and 'ylim_changed' and the callback will be called with
#  |  func(*ax*) where *ax* is the `Axes` instance.
#  |
#  |  Attributes
#  |  ----------
#  |  dataLim : `.Bbox`
#  |      The bounding box enclosing all data displayed in the Axes.
#  |  viewLim : `.Bbox`
#  |      The view limits in data coordinates.
#  |
#  |  Method resolution order:
#  |      Axes
# ...

# %%
fig, ax = plt.subplots(2,3)

# %%
ax[1][2].plot(age, salary)
plt.tight_layout()
fig

# %%
fig, ax = plt.subplots(2,2,figsize=(8,5), sharey=True, sharex=True)

# %%
plt.subplots(1,2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
plt.subplots(2,1)
plt.subplots(1,2)
plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.plot(age, salary, 'r')
plt.subplot(2,2,2)
plt.plot(age, salary, 'b')
plt.subplot(2,2,3)
plt.plot(age, salary_2, 'g')
plt.subplot(2,2,4)
plt.plot(age, salary_2, 'y')
plt.tight_layout()

# %%
ax[0,0].plot(age,salary,'r')
ax[0,0].set_title('salary by age')
ax[0,1].plot(age,salary_2,'b')
ax[0,1].set_title('salary_2 by age')
ax[1,0].plot(age,salary,'g')
ax[1,0].set_title('salary and age in green')
ax[1,1].plot(age,salary_2,'y')
ax[1,1].set_title('salary by age again')
fig
rows=2;cols=3
# for r in rows:
#     for c in cols:
fig.subplots_adjust(
    left=None,
    right=None,
    top=None,
    wspace=.9,
    hspace=.5)
fig

# %% [markdown]
# https://matplotlib.org/2.0.2/examples/showcase/anatomy.html
# This figure shows the name of several matplotlib elements composing a figure

# %% [markdown]
# # Pat 2

# %%
matplotlib.__class__

# %%
age = [25,27,29,31,33,35,37,39,41,43,45]
salary = [38496, 42000,46752,49320,53200,
          56000,62316,64928,67317,68748,73752]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998,70003, 70000, 71496, 75370, 83640]

# %%
df = pd.DataFrame(list(zip(age,salary,salary_2)),
                  columns= ['age','salary','salary_2'])
df.head(3)

# %%
fig = plt.figure(figsize=(8,4))
fig

# %%
plt.figure()

# %%
fig, ax = plt.subplots()
ax

# %%
ax.plot(age,salary, 'r')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('Age and Salary')
fig

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
ax[0].plot(age,salary)
ax[0].plot(age,salary_2)
ax[0].set_xlabel('age')
ax[0].set_ylabel('salary again')
ax[0].set_title('First Title')
ax[1].plot(age,salary)
ax[1].set_xlabel('second age')
ax[1].set_title('Second Title')
fig

# %%
fig,ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary)
ax.set_xlim([30,40])
ax.set_ylim([45_000,60_000])
fig

# %%
fig,ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary)
ax.axvline(x=35, color='orange', ls='--')
ax.axhline(y=60_000, color='orange', ls='--')
fig

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(5,3))
ax[0].plot(age,salary)
ax[0].set_xlabel('x label again')
ax[0].set_title('Title for First')
ax[1].plot(age,salary_2)
ax[1].set_xlabel('x label again')
ax[1].set_title('Title for Second')
fig

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, 
                      figsize=(5,3),
                      sharex=True, sharey=True)
ax[0].plot(age,salary)
ax[0].set_xlabel('x label again')
ax[0].set_title('Title for First')
ax[1].plot(age,salary_2)
ax[1].set_xlabel('x label again')
ax[1].set_title('Title for Second')
plt.tight_layout()
fig

# %%
fig.savefig('some_cool_chart.pdf')

# %%
fig.savefig('some_cool_chart.jpg')

# %%
fig.savefig('some_cool_chart.png')

# %%
import os
os.listdir()

# %%
fig, ax = plt.subplots(figsize=(12,3))
ax.plot(age,salary, label='salary')
ax.plot(age,salary_2, label='salary_2')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('Super-duper at the Top')
ax.legend(loc=1)  #Tray loc=2
fig

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(age,salary)
ax.set_xlabel('You are Too old')
ax.set_ylabel('You don\'t make enough money')
ax.plot(age,salary_2)
ax.set_title('Yet Another Cool Title')
ax.set_xlabel('You are Too old')
ax.set_ylabel('You don\'t make enough money')
ax.legend(loc=(.5,.5))  #Tray loc=(0,0)
fig

# %%
ticks = [25, 32.75, 40, 41, 45]
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age,salary, label='salary')
ax.plot(age,salary_2, label='salary_2')
ax.set_ylabel('salary')
ax.set_title('My Awesome Title')
ax.set_xticks(ticks)
ax.set_xticklabels(ticks)

# %%
my_list = ['very young', 'young', 'mid-age]', 'up-mid-age', 'exp', 'old goat']
labels = [25, 29, 33, 37, 41, 45]

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age,salary, label='salary_1')
ax.set_xlabel('age')
ax.plot(age,salary_2, label='salary_2')
ax.set_xlabel('age')
ax.set_ylabel('Salary')
ax.set_title('Title')
ax.set_xticks(labels)
ax.set_xticklabels(my_list, rotation=45)
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age,salary, label='salary_1')
ax.set_xlabel('age')
ax.plot(age,salary_2, label='salary_2')
ax.set_xlabel('age')
ax.set_ylabel('Salary')
ax.set_title('Title')
ax.set_xticks(labels)
ax.set_xticklabels(my_list, rotation=45)
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age,salary, label='salary')
ax.set_xlabel('age')
ax.set_ylabel('Salary')
ax.set_title('Title')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r', lw=13)
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'g', lw=3, linestyle=':')
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'g', lw=3, linestyle=':', marker='x')
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'g', lw=3, linestyle=':', marker='')
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age,salary, 'g', lw=3, linestyle=' ', marker='x')
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'g', lw=3, linestyle=' ', marker='x', markersize=20, markeredgecolor='r')
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'g', lw=3, linestyle='-.', marker='x', markersize=20, markeredgecolor='r')

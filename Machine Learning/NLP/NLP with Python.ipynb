# %%
import nltk

# %%
from nltk.corpus import stopwords
stopwords.words('English')[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
stopwords.words('English')[0:500:25]
# Out:
# ['i', 'herself', 'been', 'with', 'here', 'very', 'doesn', 'won']

# %%
rawdata = open('SMSSpamCollection.tsv').read()
rawdata[0:5]
# Out:
# 'ham\tG'

# %%
parsedData = rawdata.replace('\t', '\n').split('\n')
parsedData
# Out:
# ['ham',
#  'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'ham',
#  'Ok lar... Joking wif u oni...',
#  'spam',
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'ham',
#  'U dun say so early hor... U c already then say...',
#  'ham',
#  "Nah I don't think he goes to usf, he lives around here though",
#  'spam',
#  "FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv",
#  'ham',
#  'Even my brother is not like to speak with me. They treat me like aids patent.',
#  'ham',
#  "As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
#  'spam',
# ...

# %%
labelList = parsedData[0::2]
textList = parsedData[1::2]

# %%
print(labelList[0:5])
print(textList[0:5])
# Out:
# ['ham', 'ham', 'spam', 'ham', 'ham']
# ['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'Ok lar... Joking wif u oni...', "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'U dun say so early hor... U c already then say...', "Nah I don't think he goes to usf, he lives around here though"]

# %%
import pandas as pd
fullCorpus = pd.DataFrame({
    'label': labelList,
    'body_text': textList
})

# %%
print(len(labelList))
print(len(textList))
# Out:
# 5574
# 5574

# %%
print(labelList[-5:])
# Out:
# ['spam', 'ham', 'ham', 'ham', 'ham']

# %%
fullCorpus.head()
# Out:
#   label                                          body_text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
dataset = pd.DataFrame(fullCorpus[:])
dataset.head()
# Out:
#   label                                          body_text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# dataset = pd.read_csv('SMSSpamCollection.tsv', sep='\t', header=None)
# dataset.head()

# %%
# fullCorpus=pd.read_csv('SMSSpamCollection.tsv', sep='\t', header=None)

# %%
fullCorpus.shape
# Out:
# (5574, 2)

# %%
print('Input data has {} rows and {} columns'.format(len(fullCorpus), len(fullCorpus.columns)))
# Out:
# Input data has 5574 rows and 2 columns

# %%
nrows, ncolumns = fullCorpus.shape
print('Input data has {} rows and {} columns'.format(nrows, ncolumns))
# Out:
# Input data has 5574 rows and 2 columns

# %%
fullCorpus.iloc[:,0].value_counts()
# Out:
# ham     4827
# spam     747
# Name: label, dtype: int64

# %%
len(fullCorpus), len(fullCorpus[fullCorpus['label']=='ham']), len(fullCorpus[fullCorpus['label']=='spam'])
# Out:
# (5574, 4827, 747)

# %%
print('Out of {} rows, {} are spam, {} are ham.'. format(
        len(fullCorpus), 
        len(fullCorpus[fullCorpus['label']=='ham']), 
        len(fullCorpus[fullCorpus['label']=='spam'])
        ))
# Out:
# Out of 5574 rows, 4827 are spam, 747 are ham.

# %%
fullCorpus.isnull().sum()
# Out:
# label        0
# body_text    0
# dtype: int64

# %%
fullCorpus['label'].isnull().sum(), fullCorpus['body_text'].isnull().sum()
# Out:
# (0, 0)

# %%
print('Number of null in label: {}'.format(fullCorpus['label'].isnull().sum()))
print('Number of null in text: {}'.format(fullCorpus['body_text'].isnull().sum()))
# Out:
# Number of null in label: 0
# Number of null in text: 0
